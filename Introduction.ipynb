# %% [markdown]
# # Introduction
#
# For an Introduction to Jupyter Notebooks, please refer to the manual:
#
# * https://jupyter.org
#
# For the *Fracture and Damage Mechanics* exercise, open the notebook from the menu on the left.
